# %%
import pandas as pd 

print("HELLO")
# Out:
# HELLO

# %% [markdown]
# Here i saw how many rows or how many data points do i have

# %%
path="House_Prices_Kaggle/train.csv"

train=pd.read_csv(path)


print("There are "+str(len(train.index))+" Rows in data")
train.head()
# Out:
# There are 1460 Rows in data
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
# ...

# %% [markdown]
# Seeing Data to detect patterns... i guess

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt
histooo=train.hist(bins=150, figsize=(20,35))
plt.savefig('historgram.pdf')
plt.show()

# %% [markdown]
# Here i check for corr, and i need to remember that this corr  thingy detects only linear relationships

# %%
corr_matrix=train.corr()
corr_matrix['SalePrice'].sort_values(ascending=False)
# Out:
# SalePrice        1.000000
# OverallQual      0.790982
# GrLivArea        0.708624
# GarageCars       0.640409
# GarageArea       0.623431
# TotalBsmtSF      0.613581
# 1stFlrSF         0.605852
# FullBath         0.560664
# TotRmsAbvGrd     0.533723
# YearBuilt        0.522897
# YearRemodAdd     0.507101
# GarageYrBlt      0.486362
# MasVnrArea       0.477493
# Fireplaces       0.466929
# BsmtFinSF1       0.386420
# LotFrontage      0.351799
# WoodDeckSF       0.324413
# 2ndFlrSF         0.319334
# OpenPorchSF      0.315856
# HalfBath         0.284108
# LotArea          0.263843
# BsmtFullBath     0.227122
# BsmtUnfSF        0.214479
# BedroomAbvGr     0.168213
# ScreenPorch      0.111447
# PoolArea         0.092404
# MoSold           0.046432
# 3SsnPorch        0.044584
# BsmtFinSF2      -0.011378
# BsmtHalfBath    -0.016844
# MiscVal         -0.021190
# Id              -0.021917
# LowQualFinSF    -0.025606
# YrSold          -0.028923
# OverallCond     -0.077856
# ...

# %% [markdown]
# Here i will plot features to like detect non-linear corr by eye, but what to do when i cant do that?..
# nvm, i cant here e.e

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-57c52b9d771a> in <module>
#       1 from pandas.plotting import scatter_matrix
# ----> 2 scatter_matrix(train)
#
# c:\users\shado\onedrive\desktop\ml\ml_env\lib\site-packages\pandas\plotting\_misc.py in scatter_matrix(frame, alpha, figsize, ax, grid, diagonal, marker, density_kwds, hist_kwds, range_padding, **kwargs)
#     126     """
#     127     plot_backend = _get_plot_backend("matplotlib")
# --> 128     return plot_backend.scatter_matrix(
#     129         frame=frame,
#     130         alpha=alpha,
#
# c:\users\shado\onedrive\desktop\ml\ml_env\lib\site-packages\pandas\plotting\_matplotlib\misc.py in scatter_matrix(frame, alpha, figsize, ax, grid, diagonal, marker, density_kwds, hist_kwds, range_padding, **kwds)
#      37     n = df.columns.size
#      38     naxes = n * n
# ...

# %% [markdown]
# ## Here i detect stuff with nan values, remove features with more than 10% nan and datapoint with less than 10% nvn feautre

# %%
train=pd.read_csv(path)
null_values=train.isna().sum()
dropped_features=[]
# print(null_values)
# print(null_values.loc['Id'])
print(null_values.sort_values(ascending=False)/len(train)*100)
print("TOTAL ROWS LENGTHS before IS "+str(len(train)))
for null_indx,null_value in null_values.items():
    percent=(null_value/len(train))
    if  percent<0.1 and percent>0:
        train = train[train[null_indx].notna()]
    elif percent>=0.1:
        train=train.drop(columns=[null_indx])
        dropped_features.append(null_indx)
        
null_values=train.isna().sum()
#         null_values=null_values.drop(labels=[null_indx])
print("TOTAL ROWS LENGTHS IS "+str(len(train)))
print(null_values.sort_values(ascending=False)/len(train)*100)
# Out:
# PoolQC         99.520548
# MiscFeature    96.301370
# Alley          93.767123
# Fence          80.753425
# FireplaceQu    47.260274
#                  ...
# ExterQual       0.000000
# Exterior2nd     0.000000
# Exterior1st     0.000000
# RoofMatl        0.000000
# SalePrice       0.000000
# Length: 81, dtype: float64
# TOTAL ROWS LENGTHS before IS 1460
# TOTAL ROWS LENGTHS IS 1338
# Id              0.0
# GarageYrBlt     0.0
# Fireplaces      0.0
# Functional      0.0
# TotRmsAbvGrd    0.0
#                ...
# MasVnrArea      0.0
# MasVnrType      0.0
# Exterior2nd     0.0
# Exterior1st     0.0
# SalePrice       0.0
# Length: 75, dtype: float64

# %% [markdown]
# mmkay now i wanna see what has high corelation and at the same time have high nan values to see what i wanna do with those

# %%
corr_matrix=train.corr()
corr_result=corr_matrix['SalePrice'].sort_values(ascending=False)
corr_result
# Out:
# SalePrice        1.000000
# OverallQual      0.783546
# GrLivArea        0.711706
# GarageCars       0.640154
# GarageArea       0.607535
# 1stFlrSF         0.604714
# TotalBsmtSF      0.602042
# FullBath         0.569313
# TotRmsAbvGrd     0.551821
# YearBuilt        0.504297
# YearRemodAdd     0.501435
# GarageYrBlt      0.481730
# MasVnrArea       0.465811
# Fireplaces       0.445434
# BsmtFinSF1       0.359677
# OpenPorchSF      0.322786
# 2ndFlrSF         0.311354
# WoodDeckSF       0.305983
# HalfBath         0.258175
# LotArea          0.254757
# BsmtFullBath     0.209695
# BsmtUnfSF        0.191689
# BedroomAbvGr     0.169266
# ScreenPorch      0.096624
# PoolArea         0.091881
# 3SsnPorch        0.042159
# MoSold           0.041310
# LowQualFinSF    -0.009992
# MiscVal         -0.016990
# YrSold          -0.020451
# BsmtHalfBath    -0.030175
# Id              -0.030473
# BsmtFinSF2      -0.031226
# MSSubClass      -0.079599
# OverallCond     -0.108627
# ...

# %%
dropped_features
# Out:
# ['LotFrontage', 'Alley', 'FireplaceQu', 'PoolQC', 'Fence', 'MiscFeature']

# %% [markdown]
# Choosing High correlation features

# %%
high_corr_features=[]

for indx,result in corr_result.items():
    if(result>0.5):
        high_corr_features.append(indx)
        
high_corr_features
# Out:
# ['SalePrice',
#  'OverallQual',
#  'GrLivArea',
#  'GarageCars',
#  'GarageArea',
#  '1stFlrSF',
#  'TotalBsmtSF',
#  'FullBath',
#  'TotRmsAbvGrd',
#  'YearBuilt',
#  'YearRemodAdd']

# %% [markdown]
# making training data

# %%
high_corr_features.remove('SalePrice')
x_train,y_train=train[high_corr_features],train['SalePrice']

# %%
y_train
# Out:
# 0       208500
# 1       181500
# 2       223500
# 3       140000
# 4       250000
#          ...
# 1455    175000
# 1456    210000
# 1457    266500
# 1458    142125
# 1459    147500
# Name: SalePrice, Length: 1338, dtype: int64

# %%
from sklearn.linear_model import LinearRegression
reg=LinearRegression().fit(x_train,y_train)
predictions=reg.predict(x_train)
print(predictions[:5])
print(y_train[:5])


plt.plot(y_train[:5], predictions[:5])
# Out:
# [215587.19992376 166709.52847679 219638.41523171 205687.06325652
#  287822.61721982]
# 0    208500
# 1    181500
# 2    223500
# 3    140000
# 4    250000
# Name: SalePrice, dtype: int64

# %%
from sklearn.metrics import mean_absolute_error
val_maee = mean_absolute_error(predictions, y_train,multioutput='raw_values')
print(predictions)
print(val_maee)
print("mean is :",val_maee.mean())
print("std_dev is : ",val_maee.std())
# Out:
# [23960.36893444]
# mean is : 23960.368934441158
# std_dev is :  0.0
